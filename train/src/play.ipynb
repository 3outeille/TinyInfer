# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
import tensorflow as tf
import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plt

from keras import backend as K

# parameter ==========================
wkdir = './checkpoints'
pb_filename = 'model.pb'
pbtxt_filename = 'model.pbtxt'
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.platform import gfile
with tf.Session() as sess:
    # load model from pb file
    with gfile.FastGFile(wkdir+'/'+pb_filename,'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        sess.graph.as_default()
        g_in = tf.import_graph_def(graph_def)
    # write to tensorboard (check tensorboard for each op names)
    writer = tf.summary.FileWriter(wkdir+'/log/')
    writer.add_graph(sess.graph)
    writer.flush()
    writer.close()
    
    for i, node in enumerate(graph_def.node):
        print(node)
# Out:
# WARNING:tensorflow:From <ipython-input-2-62436e76af27>:4: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# name: "conv2d_1_input"
# op: "Placeholder"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: -1
#       }
#       dim {
#         size: 28
#       }
#       dim {
#         size: 28
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
#
# name: "conv2d_1/kernel"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 1
#         }
#         dim {
#           size: 32
#         }
#       }
#       tensor_content: "\322\321.\275\304\313\022>I\"\022\276i\376\223\275\327\343\257\275\205\350\004\275xVj\276]t\337<\340/\324\275\3278\361<\224\177\022<\276b\022\274v\317\271={\277%>6\240U=\312\"D>\342F\243\276\276\353P=*o\207=2\2128=\344\2265>\223\232N=\377\232\202;+`\016\276;\223\314<\370\320b=S/d\275\203\277\355=1\230*>D\347\010\276D\376g>\331\357\027\276\364\306\261\274\225\350\363=a\216\001\274`\322\013>\331o\005\276\020\217!\276\017\236S\276\324K\255\275\276w\035\275)\323\315=ey.<\266\247\234<\341%J>#\205+=#I*>%\000\203=\375\3505\276\021\261\023>X\031\\\275o\215l\276\272\251\216=\225&\363=\004\017#=\211\314\314=]R)<\227\207\200\274\031r\253=\354\304y\274\352\014p\275v-\030\276\342%D=aK\034\276\233\004&>\336\000y=\226\267\002\2746\306\206>\nK\330=I(Z\2767\320\234\275\3574\">L\371u=\263\032)\276{g\035\276\316\352\032<\235\025\031>&\tL>\377\\\014>\224\370%\275 L\376<\216\003\273=\014\201S>\265\356\203\275\261z\357\275`\311M\276\273\253\255=L\217\023\276j\022Z>\n;\013\276\345\n\023>\010\020Q=\025,\027\276\024}\225\275\205\235\036\275q{q\276\344\237\000\276\201&E\276\256\302\201\276\333Y\226\275\035\037\300=:|\220\273i\365\276=\3201\366=]-\002>@\3372>\342(\205\273&\323\301=0\3115=\370\362\327\274Nz\241<KL\323=\033\360\t\276K\217\356=\3548L=\262\0020\275*\310d=~\273V>\006\305==\376\370\273=\'A\333\274\233%#>\231\366\037>s\313->s\377\311<kl\313\275\341\014\">\254\227\276\274\221=K=m\'\004\274\371\342\370\274{\302\222\275\256\030\375=\016J\221<\301\336\372\274S\247{\275z\321\036\2747WR\275#@\031>\273\256>=A\2273\275\253\347\"=A\323\204\275G\341\376\275H\264\014>-\023\313=\353P@>\333W\231\275\250\227Q=\036\243\374=;p\242=

# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#         dim {
#           size: 64
#         }
#       }
#       tensor_content: "\347e\215<\332i\013\275\247[\352\274g{\333;\355q\234\274.9C\274\360H\010;\t\372\331\273+zQ\274\275jB\275X{\353\274\362\360p\274\270\275\323\274\245\337Y\274\225R\334<\323>\245\273\227\356j\274\035\353\214<I\277\213\272\253\010\023\271\357\035&\274\340\375\016;.\375\374\274\013B\225;rt\t\275\313\242\n\275\036\206\005\275D\317C\274\260\0001\274\204\205b\274\352\001\252:\031\221w\274\362\006\376\274\032x\277\272\\\270\247\274\262\010\037<\034W\217;\354\206\361\274T\306\225:z\343\212\274\231G\346\274 \'>8t)g\275wS\333\274\360\271\374\274\334\327S\274\217\236\022\274\354\272\321\273\261\334\016\275Y\306\023\275\2025\370\274\317@\242\274s\357\303\274Z\035\340\273\244\257\025\2755\316\200\274J.D\274jO\207\274\345X=\2751WH<\365\221\022\275\350J\311\274\021V\231\274-~\341\274"
#     }
#   }
# }
#
# name: "conv2d_2/bias/read"
# op: "Identity"
# input: "conv2d_2/bias"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_2/bias"
#     }
#   }
# }
#
# name: "conv2d_2/convolution"
# op: "Conv2D"
# input: "conv2d_1/Relu"
# input: "conv2d_2/kernel/read"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "data_format"
#   value {
#     s: "NHWC"
#   }
# }
# attr {
#   key: "dilations"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "padding"
#   value {
#     s: "VALID"
#   }
# }
# attr {
#   key: "strides"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "use_cudnn_on_gpu"
#   value {
#     b: true
#   }
# }
#
# name: "conv2d_2/BiasAdd"
# op: "BiasAdd"
# input: "conv2d_2/convolution"
# input: "conv2d_2/bias/read"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "data_format"
#   value {
#     s: "NHWC"
#   }
# }
#
# name: "conv2d_2/Relu"
# op: "Relu"
# input: "conv2d_2/BiasAdd"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "max_pooling2d_1/MaxPool"
# op: "MaxPool"
# input: "conv2d_2/Relu"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "data_format"
#   value {
#     s: "NHWC"
#   }
# }
# attr {
#   key: "ksize"
#   value {
#     list {
#       i: 1
#       i: 2
#       i: 2
#       i: 1
#     }
#   }
# }
# attr {
#   key: "padding"
#   value {
#     s: "VALID"
#   }
# }
# attr {
#   key: "strides"
#   value {
#     list {
#       i: 1
#       i: 2
#       i: 2
#       i: 1
#     }
#   }
# }
#
# name: "dropout_1/keras_learning_phase/input"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_BOOL
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_BOOL
#       tensor_shape {
#       }
#       bool_val: false
#     }
#   }
# }
#
# name: "dropout_1/keras_learning_phase"
# op: "PlaceholderWithDefault"
# input: "dropout_1/keras_learning_phase/input"
# attr {
#   key: "dtype"
#   value {
#     type: DT_BOOL
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
#
# name: "dropout_1/cond/Switch"
# op: "Switch"
# input: "dropout_1/keras_learning_phase"
# input: "dropout_1/keras_learning_phase"
# attr {
#   key: "T"
#   value {
#     type: DT_BOOL
#   }
# }
#
# name: "dropout_1/cond/switch_t"
# op: "Identity"
# input: "dropout_1/cond/Switch:1"
# attr {
#   key: "T"
#   value {
#     type: DT_BOOL
#   }
# }
#
# name: "dropout_1/cond/pred_id"
# op: "Identity"
# input: "dropout_1/keras_learning_phase"
# attr {
#   key: "T"
#   value {
#     type: DT_BOOL
#   }
# }
#
# name: "dropout_1/cond/mul/y"
# op: "Const"
# input: "^dropout_1/cond/switch_t"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 1.0
#     }
#   }
# }
#
# name: "dropout_1/cond/mul"
# op: "Mul"
# input: "dropout_1/cond/mul/Switch:1"
# input: "dropout_1/cond/mul/y"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/mul/Switch"
# op: "Switch"
# input: "max_pooling2d_1/MaxPool"
# input: "dropout_1/cond/pred_id"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@max_pooling2d_1/MaxPool"
#     }
#   }
# }
#
# name: "dropout_1/cond/dropout/rate"
# op: "Const"
# input: "^dropout_1/cond/switch_t"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 0.25
#     }
#   }
# }
#
# name: "dropout_1/cond/dropout/Shape"
# op: "Shape"
# input: "dropout_1/cond/mul"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "out_type"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "dropout_1/cond/dropout/sub/x"
# op: "Const"
# input: "^dropout_1/cond/switch_t"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 1.0
#     }
#   }
# }
#
# name: "dropout_1/cond/dropout/sub"
# op: "Sub"
# input: "dropout_1/cond/dropout/sub/x"
# input: "dropout_1/cond/dropout/rate"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform/min"
# op: "Const"
# input: "^dropout_1/cond/switch_t"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 0.0
#     }
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform/max"
# op: "Const"
# input: "^dropout_1/cond/switch_t"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 1.0
#     }
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform/RandomUniform"
# op: "RandomUniform"
# input: "dropout_1/cond/dropout/Shape"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "seed"
#   value {
#     i: 87654321
#   }
# }
# attr {
#   key: "seed2"
#   value {
#     i: 2215104
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform/sub"
# op: "Sub"
# input: "dropout_1/cond/dropout/random_uniform/max"
# input: "dropout_1/cond/dropout/random_uniform/min"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform/mul"
# op: "Mul"
# input: "dropout_1/cond/dropout/random_uniform/RandomUniform"
# input: "dropout_1/cond/dropout/random_uniform/sub"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/random_uniform"
# op: "Add"
# input: "dropout_1/cond/dropout/random_uniform/mul"
# input: "dropout_1/cond/dropout/random_uniform/min"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/add"
# op: "Add"
# input: "dropout_1/cond/dropout/sub"
# input: "dropout_1/cond/dropout/random_uniform"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/Floor"
# op: "Floor"
# input: "dropout_1/cond/dropout/add"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/truediv"
# op: "RealDiv"
# input: "dropout_1/cond/mul"
# input: "dropout_1/cond/dropout/sub"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/dropout/mul"
# op: "Mul"
# input: "dropout_1/cond/dropout/truediv"
# input: "dropout_1/cond/dropout/Floor"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "dropout_1/cond/Switch_1"
# op: "Switch"
# input: "max_pooling2d_1/MaxPool"
# input: "dropout_1/cond/pred_id"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@max_pooling2d_1/MaxPool"
#     }
#   }
# }
#
# name: "dropout_1/cond/Merge"
# op: "Merge"
# input: "dropout_1/cond/Switch_1"
# input: "dropout_1/cond/dropout/mul"
# attr {
#   key: "N"
#   value {
#     i: 2
#   }
# }
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "flatten_1/Shape"
# op: "Shape"
# input: "dropout_1/cond/Merge"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "out_type"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "flatten_1/strided_slice/stack"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#         dim {
#           size: 1
#         }
#       }
#       int_val: 1
#     }
#   }
# }
#
# name: "flatten_1/strided_slice/stack_1"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#         dim {
#           size: 1
#         }
#       }
#       int_val: 0
#     }
#   }
# }
#
# name: "flatten_1/strided_slice/stack_2"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#         dim {
#           size: 1
#         }
#       }
#       int_val: 1
#     }
#   }
# }
#
# name: "flatten_1/strided_slice"
# op: "StridedSlice"
# input: "flatten_1/Shape"
# input: "flatten_1/strided_slice/stack"
# input: "flatten_1/strided_slice/stack_1"
# input: "flatten_1/strided_slice/stack_2"
# attr {
#   key: "Index"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "begin_mask"
#   value {
#     i: 0
#   }
# }
# attr {
#   key: "ellipsis_mask"
#   value {
#     i: 0
#   }
# }
# attr {
#   key: "end_mask"
#   value {
#     i: 1
#   }
# }
# attr {
#   key: "new_axis_mask"
#   value {
#     i: 0
#   }
# }
# attr {
#   key: "shrink_axis_mask"
#   value {
#     i: 0
#   }
# }
#
# name: "flatten_1/Const"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#         dim {
#           size: 1
#         }
#       }
#       int_val: 0
#     }
#   }
# }
#
# name: "flatten_1/Prod"
# op: "Prod"
# input: "flatten_1/strided_slice"
# input: "flatten_1/Const"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "Tidx"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "keep_dims"
#   value {
#     b: false
#   }
# }
#
# name: "flatten_1/stack/0"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: -1
#     }
#   }
# }
#
# name: "flatten_1/stack"
# op: "Pack"
# input: "flatten_1/stack/0"
# input: "flatten_1/Prod"
# attr {
#   key: "N"
#   value {
#     i: 2
#   }
# }
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "axis"
#   value {
#     i: 0
#   }
# }
#
# name: "flatten_1/Reshape"
# op: "Reshape"
# input: "dropout_1/cond/Merge"
# input: "flatten_1/stack"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "Tshape"
#   value {
#     type: DT_INT32
#   }
# }
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
