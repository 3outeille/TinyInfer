# %%
"""
Helper file for visualize the saved pb model
"""

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
import tensorflow as tf
import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plt

from keras import backend as K
from tensorflow.python.framework import tensor_util

import json

# parameter ==========================
wkdir = '../../data'
pb_filename = 'model.pb'
pbtxt_filename = 'model.pbtxt'
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.platform import gfile
with tf.Session() as sess:
    # load model from pb file
    with gfile.FastGFile(wkdir+'/'+pb_filename,'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        sess.graph.as_default()
        g_in = tf.import_graph_def(graph_def)
    # write to tensorboard (check tensorboard for each op names)
    writer = tf.summary.FileWriter(wkdir+'/log/')
    writer.add_graph(sess.graph)
    writer.flush()
    writer.close()
    
    for i, node in enumerate(graph_def.node):
        # print(node)
        if ('value' in node.attr):
            # print(node.name)
            # print(node.attr['shape'])
            tensor_np = tensor_util.MakeNdarray(node.attr['value'].tensor)
            print(tensor_np)
        # print(node.attr['shape'])
        # if (i == 10):
        #     break
# Out:
# WARNING:tensorflow:From <ipython-input-2-0b4200188d5d>:4: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# [[[[-4.33983877e-02  1.36150271e-01 -1.18125536e-01 -7.00390339e-02
#     -8.54113549e-02 -2.90465504e-02 -2.40067080e-01  2.20960211e-02
#     -1.05361342e-01  2.87708435e-02  1.76449325e-02 -1.40909329e-02
#      9.26809460e-02  1.57984748e-01  4.66626436e-02  1.79081798e-01
#     -3.00222725e-01  5.13001382e-02  5.45427166e-02  4.17214744e-02
#      1.73075885e-01  4.67458814e-02 -8.30795988e-03 -1.36598766e-01
#      2.33299993e-02  5.41800484e-02 -5.72361015e-02  1.16228521e-01
#      1.61881939e-01 -1.32285953e-01  2.16926321e-01 -1.43252641e-01]]
#
#   [[-1.66454744e-02  1.14922732e-01 -2.60199956e-03  1.27879038e-01
#     -1.35162830e-01 -1.67067856e-01 -2.11001769e-01 -9.50312614e-02
#     -4.50071208e-02  1.00826196e-01  1.49122691e-02  2.34806072e-02
# ...

# %%
from tensorflow.python.platform import gfile
with tf.Session() as sess:
    # load model from pb file
    with gfile.FastGFile(wkdir+'/'+pb_filename,'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        sess.graph.as_default()
        g_in = tf.import_graph_def(graph_def)
    # write to tensorboard (check tensorboard for each op names)
    writer = tf.summary.FileWriter(wkdir+'/log/')
    writer.add_graph(sess.graph)
    writer.flush()
    writer.close()
    
    for i, node in enumerate(graph_def.node):
        # print(node)
#         if ('value' in node.attr):
#             print(type(node.attr['value'].tensor))
#             print(node.attr['value'].tensor)
        print ("====================================")
        print(node.name)
        if (node.op == "Conv2D"):
            print(node)
        print(node.op)
        print(node.input)
        if (i == 100):
            break
# Out:
# ...
# conv2d_1_input
# Placeholder
# []
# ...
# conv2d_1/kernel
# Const
# []
# ...
# conv2d_1/kernel/read
# Identity
# ['conv2d_1/kernel']
# ...
# conv2d_1/bias
# Const
# []
# ...
# conv2d_1/bias/read
# Identity
# ['conv2d_1/bias']
# ...
# conv2d_1/convolution
# name: "conv2d_1/convolution"
# op: "Conv2D"
# input: "conv2d_1_input"
# input: "conv2d_1/kernel/read"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "data_format"
#   value {
#     s: "NHWC"
#   }
# }
# attr {
#   key: "dilations"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "padding"
#   value {
#     s: "VALID"
#   }
# }
# attr {
#   key: "strides"
#   value {
#     list {
#       i: 1
#       i: 1
#       i: 1
#       i: 1
#     }
#   }
# }
# attr {
#   key: "use_cudnn_on_gpu"
#   value {
#     b: true
#   }
# }
#
# Conv2D
# ['conv2d_1_input', 'conv2d_1/kernel/read']
# ...
# conv2d_1/BiasAdd
# BiasAdd
# ['conv2d_1/convolution', 'conv2d_1/bias/read']
# ...

# %%
from tensorflow.python.platform import gfile
with tf.Session() as sess:
    # load model from pb file
    with gfile.FastGFile(wkdir+'/'+pb_filename,'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        sess.graph.as_default()
        g_in = tf.import_graph_def(graph_def)
    # write to tensorboard (check tensorboard for each op names)
    writer = tf.summary.FileWriter(wkdir+'/log/')
    writer.add_graph(sess.graph)
    writer.flush()
    writer.close()
    
    tensor_output = sess.graph.get_tensor_by_name('import/dense_2/Softmax:0')
    
    tesnor_conv1_kernal = sess.graph.get_tensor_by_name('import/conv2d_1/kernel:0')
    tesnor_conv2_kernal = sess.graph.get_tensor_by_name('import/conv2d_2/kernel:0')
    # print(sess.run(tesnor_conv1_kernal))
    
    tensor_conv1_bias = sess.graph.get_tensor_by_name('import/conv2d_1/bias:0')
    tensor_conv2_bias = sess.graph.get_tensor_by_name('import/conv2d_2/bias:0')
    print(tesnor_conv2_kernal.shape)
    print(sess.run(tesnor_conv2_kernal[0,1,0,0]))
    print(sess.run(tesnor_conv2_kernal))
